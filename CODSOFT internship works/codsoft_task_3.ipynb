# %% [markdown]
# #       TASK : SALES PREDICTION USING PYTHON
#
#     Author:Debasmita saha
#
#     Batch: June Batch A60
#
#     Domain:Data Science
#
#     Aim:- Sales prediction involves predicting the amount of a product that a customer will
#     purchase, taking into account several factors such as advertising expenditure and advertising platform selection

# %% [markdown]
# #### IMPORTING IMPORTANT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### IMPORTING DATASET

# %%
df = pd.read_csv('advertising.csv')
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %% [markdown]
# The given dataset consist of the expenditure on the advertising platforms and the related sales

# %%
df.shape
# Out:
# (200, 4)

# %%
df.size
# Out:
# 800

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# Some Basic observations
#
# Advertising expense spend is highest on TV
#
# Advertising expense spend is lowest on Radio
#
# Maximum sale is 27 and Minimum sale is 1.6

# %% [markdown]
# ## Analyzing Data Graphically

# %%
sns.pairplot(df,x_vars=['TV','Radio','Newspaper'],y_vars='Sales',kind='scatter')
plt.show()

# %% [markdown]
# From the above Pair plot we come to a conclusion that
#
# When advertising cost increases in TV Ads the sales will also increase ,but for Radio and Newspaper it is bit unpredictable

# %%
plt.figure(figsize=(8,5))
sns.histplot(x='TV',data=df,kde=True)
plt.xlabel('TV',color='m',size=13)
plt.title('Histogram',color='k',size=16)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(x='Radio',data=df,kde=True)
plt.xlabel('Radio',color='m',size=13)
plt.title('Histogram',color='k',size=16)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(x='Newspaper',data=df,kde=True)
plt.xlabel('Newspaper',color='m',size=13)
plt.title('Histogram',color='k',size=16)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(x='Sales',data=df,kde=True)
plt.xlabel('Sales',color='m',size=13)
plt.title('Histogram',color='k',size=16)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='TV',data=df,y='Sales')
plt.xlabel('TV',color='m',size=13)
plt.ylabel('Sales',color='m',size=13)
plt.title('Scatterplot',color='k',size=16)
plt.show()

# %% [markdown]
# SALES IS DIRECTLY RELATED WITH THE TV
#
# Lets train our model using Linear Regression as it is related with only one variable TV

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %% [markdown]
# Splitting the dataset for training and testing

# %%
x = df[['TV']]
y = df[['Sales']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state = 0)

# %%
x_train
# Out:
#         TV
# 131  265.2
# 96   197.6
# 181  218.5
# 19   147.3
# 153  171.3
# ..     ...
# 67   139.3
# 192   17.2
# 117   76.4
# 47   239.9
# 172   19.6
#
# [140 rows x 1 columns]

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %% [markdown]
# ### Training done

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Accuracy

# %%
model.score(x_train,y_train)
# Out:
# 0.8059411537112771

# %%
x_test
# Out:
#         TV
# 18    69.2
# 170   50.0
# 107   90.4
# 98   289.7
# 177  170.2
# 182   56.2
# 5      8.7
# 146  240.1
# 12    23.8
# 152  197.6
# 61   261.3
# 125   87.2
# 180  156.6
# 154  187.8
# 80    76.4
# 7    120.2
# 33   265.6
# 130    0.7
# 37    74.7
# 74   213.4
# 183  287.6
# 145  140.3
# 45   175.1
# 159  131.7
# 60    53.5
# 123  123.1
# 179  165.6
# 185  205.0
# 122  224.0
# 44    25.1
# 16    67.8
# 55   198.9
# 150  280.7
# 111  241.7
# 22    13.2
# 189   18.7
# 129   59.6
# 4    180.8
# 83    68.4
# 106   25.0
# 134   36.9
# 66    31.5
# 26   142.9
# 113  209.6
# 168  215.4
# 63   102.7
# 8      8.6
# 75    16.9
# 118  125.7
# 143  104.6
# 71   109.8
# 124  229.5
# 184  253.8
# 97   184.9
# 149   44.7
# 24    62.3
# 30   292.9
# 160  172.5
# 40   202.5
# 56     7.3

# %%
y_pred_test=reg.predict(x_test)
y_pred_test
# Out:
# array([[10.93127621],
#        [ 9.88042193],
#        [12.09159447],
#        [22.99968079],
#        [16.45920756],
#        [10.21976029],
#        [ 7.6199906 ],
#        [20.28497391],
#        [ 8.4464437 ],
#        [17.95886418],
#        [21.44529217],
#        [11.91645209],
#        [15.71485245],
#        [17.42249065],
#        [11.32534656],
#        [13.72260788],
#        [21.68063975],
#        [ 7.18213465],
#        [11.23230217],
#        [18.82362968],
#        [22.88474361],
#        [14.82272095],
#        [16.72739433],
#        [14.35202581],
#        [10.07198391],
#        [13.88133066],
#        [16.20744039],
#        [18.36388094],
#        [19.40378881],
#        [ 8.51759529],
#        [10.85465142],
#        [18.03001578],
#        [22.50709285],
#        [20.3725451 ],
#        [ 7.86628457],
#        [ 8.16731053],
#        [10.40584907],
#        [17.03936669],
#        [10.88749061],
#        [ 8.51212209],
#        [ 9.16343282],
# ...

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,y_pred_test,color='m')
plt.xlabel('Advertising expense on TV',color='m')
plt.ylabel('Sales',color='m')
plt.title('Best Fit Line',color='k',size=16)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error
error=mean_absolute_error(y_test,y_pred_test)
print('The Mean absolute Error is:',error)
# Out:
# The Mean absolute Error is: 1.8639438916550553

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred_test)
print('The accuracy score is:',score)
# Out:
# The accuracy score is: 0.8150168765722068

# %% [markdown]
# # THE END
